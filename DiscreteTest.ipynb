# %%
import apis.Discretization as Discrete
import numpy as np

# %%
space = Discrete.Discretization(-2., 2., -2., 2., 1.0, 1.0)

# %%
space.draw()

# %%
space.get_nearest_node(np.array([2.0, 1.1]))
# Out:
# 19

# %%
space.get_node_loc(19)
# Out:
# array([2., 1.])

# %%
space.get_path(space.get_nearest_node(np.array([0.1, 0.0])), 19)
# Out:
# [array([0., 0.]), array([1., 0.]), array([2., 0.]), array([2., 1.])]

# %%
space.remove_node(14)
space.draw()
# Out:
# 0
# 5
# 10
# 15
# 20
# 1
# 6
# 11
# 16
# 21
# 2
# 7
# 12
# 17
# 22
# 3
# 8
# 13
# 18
# 23
# 4
# 9
# 19
# 24

# %%
space.get_path(space.get_nearest_node(np.array([0.1, 0.0])), 19)
# Out:
# [array([0., 0.]), array([1., 0.]), array([1., 1.]), array([2., 1.])]
